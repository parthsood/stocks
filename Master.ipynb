# %%
from nsepy import get_history
import datetime as dt
import pandas as pd
import matplotlib.pyplot as plt

# Get Name
def get_name(text):
    return print(companies[companies.Symbol == text].Company.values[0])

# %%
companies = pd.read_csv('list_of_symbols.csv')

# %%
# df = pd.DataFrame()
# for i in companies.Symbol:
#     t = get_history(symbol=i, start=dt.date.today() - dt.timedelta(days=730), end=dt.date.today())
#     df = pd.concat([df, t])
# df.to_csv('master.csv')

# %%
print(list(companies.Symbol.unique()))
# Out:
# ['POWERINDIA', 'SBICARD', 'SUVENPHAR', 'GEEKAYWIRE', 'BAFNAPH', 'ALOKINDS', 'UNIVPHOTO', 'MAHEPC', 'ASALCBR', 'BIRLATYRE', 'SHREDIGCEM', 'SUMICHEM', 'RUCHI', 'ARTEMISMED', 'TOUCHWOOD', 'DPWIRES', 'VAISHALI', 'MMP', 'PANACHE', 'PRINCEPIPE', 'SHIL', 'UJJIVANSFB', 'CSBBANK', 'CHEMBOND', 'KIRLFER', 'APOLLOPIPE', 'JASH', 'KUANTUM', 'GREENPANEL', 'FLUOROCHEM', 'VISHWARAJ', 'IRCTC', 'AKASH', 'IIFLSEC', 'IIFLWAM', 'SAFARI', 'KRISHANA', 'MBAPL', 'SWSOLAR', 'JIYAECO', 'JUMPNET', 'BCP', 'ZOTA', 'SPANDANA', 'WESTLIFE', 'VISHAL', 'DOLAT', 'VIKASPROP', 'HNDFDS', 'AFFLE', 'CREATIVE', 'SHRENIK', 'SUMIT', 'LIBAS', 'SIRCA', 'GFSTEELS', 'SATIA', 'DCMNVL', 'INFOBEAN', 'SANGINITA', 'SEYAIND', 'OAL', 'INDIAMART', 'STEELCITY', 'DGCONTENT', 'PPL', 'CONFIPET', 'GBGLOBAL', 'EMAMIPAP', 'ONEPOINT', 'NEOGEN', 'VIKASMCORP', 'AIRAN', 'KPITTECH', 'SOUTHWEST', 'POLYCAB', 'MAHESHWARI', 'METROPOLIS', 'RVNL', 'SAKAR', 'MSTCLTD', 'ARVINDFASN', 'AGROPHOS', 'ANUP', 'CHALET', 'XELPMOC', 'SPENCERS', 'CESCVENT', 'SAGARDEEP',
# ...

# %%
get_name('IRCTC')
# Out:
# Indian Railway Catering And Tourism Corporation Limited

# %%
stocks = ['SBICARD', 'IRCTC', '']

# %%
plt.figure(figsize=(16,10))

for i in df.Symbol.unique():
    t = df[df.Symbol == i]
    plt.plot(t.index, t.Close.diff(), linewidth=2, label=i)

plt.ylim(0,)
plt.legend(loc='lower left')
plt.grid()
plt.show()
